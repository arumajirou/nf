# %% [markdown]
# # nf_loto_platform AI データサイエンティスト Playground
#
# このノートブックでは、`nf_loto_platform.agents` パッケージを利用して、
# Curator → Planner → Forecaster → Reporter → Orchestrator の一連の流れを
# ローカル環境で検証するためのサンプルコードをまとめる。

# %%
from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd

# プロジェクトルートを sys.path に追加
ROOT = Path(__file__).resolve().parents[1]
sys.path.insert(0, str(ROOT / "src"))

from nf_loto_platform.agents import (
    AgentOrchestrator,
    CuratorAgent,
    EchoLLMClient,
    ForecasterAgent,
    PlannerAgent,
    ReporterAgent,
    TimeSeriesTaskSpec,
)

from nf_loto_platform.db.loto_repository import load_panel_by_loto

print("ROOT=", ROOT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 import pandas as pd
#       8 # プロジェクトルートを sys.path に追加
# ----> 9 ROOT = Path(__file__).resolve().parents[1]
#      10 sys.path.insert(0, str(ROOT / "src"))
#      12 from nf_loto_platform.agents import (
#      13     AgentOrchestrator,
#      14     CuratorAgent,
#    (...)     19     TimeSeriesTaskSpec,
#      20 )
#
# NameError: name '__file__' is not defined

# %%
# サンプルタスク定義
task = TimeSeriesTaskSpec(
    loto_kind="loto6",
    target_horizon=4,
    frequency="W",
    objective_metric="mae",
    allow_tsfm=True,
    allow_neuralforecast=True,
    allow_classical=False,
    max_training_time_minutes=10.0,
    mode="auto",
)
task
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # サンプルタスク定義
# ----> 2 task = TimeSeriesTaskSpec(
#       3     loto_kind="loto6",
#       4     target_horizon=4,
#       5     frequency="W",
#       6     objective_metric="mae",
#       7     allow_tsfm=True,
#       8     allow_neuralforecast=True,
#       9     allow_classical=False,
#      10     max_training_time_minutes=10.0,
#      11     mode="auto",
#      12 )
#      13 task
#
# NameError: name 'TimeSeriesTaskSpec' is not defined

# %%
# 依存コンポーネントを組み立て
llm = EchoLLMClient(max_chars=512)
curator = CuratorAgent(llm_client=llm)
planner = PlannerAgent()
forecaster = ForecasterAgent()
reporter = ReporterAgent(llm_client=llm)

orchestrator = AgentOrchestrator(
    curator=curator,
    planner=planner,
    forecaster=forecaster,
    reporter=reporter,
)
orchestrator
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 依存コンポーネントを組み立て
# ----> 2 llm = EchoLLMClient(max_chars=512)
#       3 curator = CuratorAgent(llm_client=llm)
#       4 planner = PlannerAgent()
#
# NameError: name 'EchoLLMClient' is not defined

# %%
# 実際の nf_loto_* テーブルが存在する環境でのみ実行してください。
# 注意: このセルは DB に接続し、実験を実行します。

TABLE_NAME = "nf_loto_panel"  # 実際の環境に合わせて変更
LOTO = "loto6"
UNIQUE_IDS = ["default"]  # 実際の unique_id に合わせて変更

outcome, report = orchestrator.run_full_cycle(
    task=task,
    table_name=TABLE_NAME,
    loto=LOTO,
    unique_ids=UNIQUE_IDS,
)

outcome, report.summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 LOTO = "loto6"
#       6 UNIQUE_IDS = ["default"]  # 実際の unique_id に合わせて変更
# ----> 8 outcome, report = orchestrator.run_full_cycle(
#       9     task=task,
#      10     table_name=TABLE_NAME,
#      11     loto=LOTO,
#      12     unique_ids=UNIQUE_IDS,
#      13 )
#      15 outcome, report.summary
#
# NameError: name 'orchestrator' is not defined
