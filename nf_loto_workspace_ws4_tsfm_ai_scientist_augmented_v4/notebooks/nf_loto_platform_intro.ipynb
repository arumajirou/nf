# %% [markdown]
# # nf_loto_platform intro
#
# NeuralForecast Loto Suite 統合環境のイントロノートブックです。

# %%
from nf_loto_platform.core import settings
from nf_loto_platform.pipelines.training_pipeline import run_legacy_nf_auto_runner

db_cfg = settings.load_db_config()
db_cfg
# Out:
# {'host': 'localhost',
#  'port': 5432,
#  'database': 'postgres',
#  'user': 'postgres',
#  'password': 'z'}
